# %% [markdown]
# # Source: https://scikit-learn.org/stable/auto_examples/decomposition/plot_image_denoising.html

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"

import numpy as np
import sklearn
import scipy.linalg as LA
import matplotlib.pyplot as plt
from sklearn.decomposition import SparseCoder, sparse_encode
from sklearn.linear_model import orthogonal_mp_gram


seed = 42
rng = np.random.default_rng(seed)

# %% [markdown]
# ## Import test image from scipy

# %%
from scipy.datasets import face

raccoon_face = face(gray=True).astype(np.float64)

# normalize
raccoon_face /= 255.0

# downsample for speed
raccoon_face = raccoon_face[::4, ::4] + raccoon_face[2::4, ::4] + raccoon_face[::4, 2::4] + raccoon_face[2::4, 2::4]
raccoon_face /= 4
height, width = raccoon_face.shape

# Distort the right half of the image
print('Distorting image')
distorted = raccoon_face.copy()
distorted[:, width // 2:] += .075 * rng.standard_normal(size=(height, width // 2))
# Out:
# Distorting image

# %% [markdown]
# ## Display distorted image

# %%
def show_with_diff(image, reference, title):
    plt.figure(figsize=(7, 3.3))
    plt.subplot(1, 2, 1)
    plt.title('Image')
    plt.imshow(image, vmin=0, vmax=1, cmap=plt.cm.gray, interpolation='nearest')
    plt.xticks(())
    plt.yticks(())
    
    plt.subplot(1, 2, 2)
    difference = image - reference

    plt.title('Difference (norm: %.2f)' % np.sqrt(np.sum(difference**2)))
    plt.imshow(
        difference, vmin=-0.5, vmax=0.5, cmap=plt.cm.PuOr, interpolation='nearest'
    )
    plt.xticks(())
    plt.yticks(())
    plt.suptitle(title, size=16)
    plt.subplots_adjust(.02, .02, .98, .79, .02, .2)

show_with_diff(distorted, raccoon_face, 'Distorted image')

# %% [markdown]
# ## Extract reference patches

# %%
from time import time
from sklearn.feature_extraction.image import extract_patches_2d

# Extract patches from left half of the image
print('Extracting reference patches')
t0 = time()
patch_size = (7, 7)
data = extract_patches_2d(distorted[:, :width // 2], patch_size)
data = data.reshape(data.shape[0], -1)
data -= np.mean(data, axis=0)
data /= np.std(data, axis=0)
print(f'{data.shape[0]} patches extracted in %.2fs.' % (time() - t0))
# Out:
# Extracting reference patches
# 22692 patches extracted in 0.01s.

# %% [markdown]
# # Baseline (Almost Serial_V2.py)

# %%
def kSVD_baseline(Y, T_0, k, num_iter, track_loss = True, verbose:int = 0, rng=42):
    loss = np.empty(num_iter)
    rng = np.random.default_rng(rng)

    # Initialize dictionary
    t0 = time()
    D = rng.standard_normal(size=(k, Y.shape[1]))
    D = (1 / LA.norm(D, ord=2, axis=1))[:, np.newaxis] * D

    if verbose > 0:
        print(f'Initialization Time: {time() - t0}')
    
    for iter in range(num_iter):
        t0 = 0
        if verbose > 0:
            print(f'Iteration {iter}:')
            t0 = time()
        
        # X = SparseCoder(dictionary = D, transform_n_nonzero_coefs = T_0).transform(Y)
        gram = D @ D.T
        cov = D @ Y.T
        X = sparse_encode(Y, 
                          D, #n_jobs=1,
                          algorithm='omp', 
                          n_nonzero_coefs = T_0,
                          gram = gram,
                          cov = cov,
                          copy_cov=False)
        if verbose > 0:
            print(f'\tCoding Time: {time() - t0}')
        
        t0 = time()
        unused_atom = False
        XD = X @ D
        for i in range(k):
            x_i = X[:, i]
            filter = (x_i != 0)
            x_i_R = x_i[filter]
            if x_i_R.shape[0] == 0:
                unused_atom=True
                continue

            # E_k_R = Y[filter]
            # E_k_R -= X[filter] @ D - X[filter, i][:, None] * D[i]
            XD[filter] -= X[filter, i][:, np.newaxis] * D[i]
            E_k_R = Y[filter] - XD[filter]

            U, S, Vh = LA.svd(E_k_R, full_matrices=False)

            X[filter, i] = U[:, 0] * S[0]
            D[i] = Vh[0]

            XD[filter] += X[filter, i][:, np.newaxis] * D[i]

        if verbose > 0:
            print(f'\tUpdate Time: {time() - t0}')
            print(f'\tUnused Atom: {unused_atom}')
        
        loss[iter] = LA.norm(Y - X @ D, ord='fro')

    return D, loss

# %% [markdown]
# # Improved Implementation (Serial_V2_1.py)

# %%
def kSVD_improved(Y, T_0, k, num_iter, track_loss = True, verbose:int = 0, rng=42):
    loss = np.empty(num_iter)
    rng = np.random.default_rng(rng)

    # Initialize dictionary
    t0 = time()
    D = rng.standard_normal(size=(k, Y.shape[1]))
    D /= LA.norm(D, ord=2, axis=1)[:, np.newaxis]

    if verbose > 0:
        print(f'Initialization Time: {time() - t0}')
    
    for iter in range(num_iter):
        t0 = 0
        if verbose > 0:
            print(f'Iteration {iter}:')
            t0 = time()
        
        gram = D @ D.T
        cov = D @ Y.T
        X = orthogonal_mp_gram(
            Gram=gram, 
            Xy=cov, 
            n_nonzero_coefs=T_0, 
            copy_Gram=False, 
            copy_Xy=False
        ).T # Transpose to match X shape
        if verbose > 0:
            print(f'\tCoding Time: {time() - t0}')
        
        t0 = time()
        unused_atom = False
        XD = X @ D
        # E_k_R = Y
        # E_k_R -= X @ D
        for i in range(k):
            x_i = X[:, i]
            # filter = (x_i != 0)
            filter = np.flatnonzero(x_i)
            x_i_R = x_i[filter]
            if x_i_R.shape[0] == 0:
                unused_atom=True
                continue
            
            res = X[filter, i][:, np.newaxis] * D[i]
            XD[filter] -= res
            E_k_R = Y[filter] - XD[filter]
            # E_k_R[filter] += X[filter, i][:, np.newaxis] * D[i]

            U, S, Vh = LA.svd(E_k_R, full_matrices=False)
            # U, S, Vh = LA.svd(E_k_R[filter], full_matrices=False)

            X[filter, i] = U[:, 0] * S[0]
            D[i] = Vh[0]

            XD[filter] += X[filter, i][:, np.newaxis] * D[i]
            # E_k_R[filter] -= X[filter, i][:, np.newaxis] * D[i]

        if verbose > 0:
            print(f'\tUpdate Time: {time() - t0}')
            print(f'\tUnused Atom: {unused_atom}')
        
        loss[iter] = LA.norm(Y - XD, ord='fro')
        # loss[iter] = LA.norm(E_k_R, ord='fro')

    return D, loss

# %%
def plot_log_loss(loss, linestyle='-', alpha = 1):
    plt.semilogy(loss, linestyle=linestyle, alpha = alpha)
    plt.title('Loss vs iterations')
    plt.xlabel('Iteration')
    plt.ylabel('Loss (Log Scale)')
    # plt.show()

# %% [markdown]
# ## Learn the dictionary from reference patches

# %% [markdown]
# ### Hyperparams have been set to try to match those in the sklearn example and the results obtained for a more fair comparison!

# %%
num_iter = 2
Y = data

# %% [markdown]
# ## Baseline

# %%
# %%timeit
D, loss = kSVD_baseline(Y = Y,
               T_0 = 1, 
               k = 300, 
               num_iter = num_iter, 
               verbose=0,
                rng = rng)
# Out:
# 3.94 s ± 83.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Improved

# %%
# %%timeit
D, loss = kSVD_improved(Y = Y,
                T_0 = 1, 
                k = 300, 
                num_iter = num_iter, 
                verbose=0,
                rng = rng)
# Out:
# 3.8 s ± 137 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
times = []
final_losses = []
for i in range(50):
    t0 = time()
    D, loss = kSVD_improved(Y = Y, 
                   T_0 = 1, 
                   k = 300, 
                   num_iter = num_iter, 
                   verbose=0,
                    rng = rng)
    times.append(time() - t0)
    final_losses.append(loss[-1])

plt.hist(times)
# Out:
# (array([ 1.,  0.,  1.,  3.,  9., 16., 13.,  2.,  2.,  3.]),
#  array([3.55020571, 3.59658253, 3.64295936, 3.68933618, 3.73571301,
#         3.78208983, 3.82846665, 3.87484348, 3.9212203 , 3.96759713,
#         4.01397395]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(times, final_losses)

# %% [markdown]
# # Going a little deeper with the profiling

# %% [markdown]
# ## See https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html for a few examples

# %% [markdown]
# ## Requires line_profiler to be installed if you want to run the following code locally !!!

# %%
# pip install line_profiler

# %%
# %load_ext line_profiler

# %%
num_iter = 2
Y = data

# %% [markdown]
# ## Baseline

# %%
from line_profiler import profile

l_kSVD_baseline = profile(kSVD_baseline)
# %lprun -f l_kSVD_baseline l_kSVD_baseline(Y = Y, \
               T_0 = 1, \
               k = 300, \
               num_iter = num_iter, \
                verbose=0, rng = rng)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 4.99313 s
# File: C:\Users\richa\AppData\Local\Temp\ipykernel_12148\2845512668.py
# Function: kSVD_baseline at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def kSVD_baseline(Y, T_0, k, num_iter, track_loss = True, verbose:int = 0, rng=42):
#      2         1        103.0    103.0      0.0      loss = np.empty(num_iter)
#      3         1         47.0     47.0      0.0      rng = np.random.default_rng(rng)
#      4
#      5                                               # Initialize dictionary
#      6         1         10.0     10.0      0.0      t0 = time()
#      7         1       1986.0   1986.0      0.0      D = rng.standard_normal(size=(k, Y.shape[1]))
#      8         1       3211.0   3211.0      0.0      D = (1 / LA.norm(D, ord=2, axis=1))[:, np.newaxis] * D
#      9
#     10         1         11.0     11.0      0.0      if verbose > 0:
#     11                                                   print(f'Initialization Time: {time() - t0}')
#     12
#     13         3         64.0     21.3      0.0      for iter in range(num_iter):
#     14         2         15.0      7.5      0.0          t0 = 0
#     15         2         10.0      5.0      0.0          if verbose > 0:
#     16                                                       print(f'Iteration {iter}:')
#     17                                                       t0 = time()
#     18
#     19                                                   # X = SparseCoder(dictionary = D, transform_n_nonzero_coefs = T_0).transform(Y)
#     20         2       5870.0   2935.0      0.0          gram = D @ D.T
#     21         2     699560.0 349780.0      1.4          cov = D @ Y.T
#     22         4   42736348.0 1.07e+07     85.6          X = sparse_encode(Y,
#     23         2          8.0      4.0      0.0                            D, #n_jobs=1,
#     24         2         16.0      8.0      0.0                            algorithm='omp',
#     25         2          3.0      1.5      0.0                            n_nonzero_coefs = T_0,
#     26         2          3.0      1.5      0.0                            gram = gram,
#     27         2          5.0      2.5      0.0                            cov = cov,
#     28         2          9.0      4.5      0.0                            copy_cov=False)
#     29         2          9.0      4.5      0.0          if verbose > 0:
#     30                                                       print(f'\tCoding Time: {time() - t0}')
#     31
#     32         2         30.0     15.0      0.0          t0 = time()
#     33         2          3.0      1.5      0.0          unused_atom = False
#     34         2     801398.0 400699.0      1.6          XD = X @ D
#     35       602       2804.0      4.7      0.0          for i in range(k):
#     36       600      47576.0     79.3      0.1              x_i = X[:, i]
#     37       600     106581.0    177.6      0.2              filter = (x_i != 0)
#     38       600      50005.0     83.3      0.1              x_i_R = x_i[filter]
#     39       600       5534.0      9.2      0.0              if x_i_R.shape[0] == 0:
#     40         4          5.0      1.2      0.0                  unused_atom=True
#     41         4          8.0      2.0      0.0                  continue
#     42
#     43                                                       # E_k_R = Y[filter]
#     44                                                       # E_k_R -= X[filter] @ D - X[filter, i][:, None] * D[i]
#     45       596     846966.0   1421.1      1.7              XD[filter] -= X[filter, i][:, np.newaxis] * D[i]
#     46       596     564948.0    947.9      1.1              E_k_R = Y[filter] - XD[filter]
#     47
#     48       596    2255664.0   3784.7      4.5              U, S, Vh = LA.svd(E_k_R, full_matrices=False)
#     49
#     50       596     286725.0    481.1      0.6              X[filter, i] = U[:, 0] * S[0]
#     51       596       9798.0     16.4      0.0              D[i] = Vh[0]
#     52
#     53       596     847233.0   1421.5      1.7              XD[filter] += X[filter, i][:, np.newaxis] * D[i]
#     54
#     55         2          7.0      3.5      0.0          if verbose > 0:
#     56                                                       print(f'\tUpdate Time: {time() - t0}')
#     57                                                       print(f'\tUnused Atom: {unused_atom}')
#     58
#     59         2     658740.0 329370.0      1.3          loss[iter] = LA.norm(Y - X @ D, ord='fro')
#     60
#     61         1          4.0      4.0      0.0      return D, loss

# %% [markdown]
# ## Improved

# %%
l_kSVD_improved = profile(kSVD_improved)
# %lprun -f l_kSVD_improved l_kSVD_improved(Y = Y, \
               T_0 = 1, \
               k = 300, \
               num_iter = num_iter, \
                verbose=0, rng = rng)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 4.97856 s
# File: C:\Users\richa\AppData\Local\Temp\ipykernel_12148\4179300726.py
# Function: kSVD_improved at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def kSVD_improved(Y, T_0, k, num_iter, track_loss = True, verbose:int = 0, rng=42):
#      2         1         75.0     75.0      0.0      loss = np.empty(num_iter)
#      3         1         38.0     38.0      0.0      rng = np.random.default_rng(rng)
#      4
#      5                                               # Initialize dictionary
#      6         1         10.0     10.0      0.0      t0 = time()
#      7         1       4191.0   4191.0      0.0      D = rng.standard_normal(size=(k, Y.shape[1]))
#      8         1       2033.0   2033.0      0.0      D /= LA.norm(D, ord=2, axis=1)[:, np.newaxis]
#      9
#     10         1          7.0      7.0      0.0      if verbose > 0:
#     11                                                   print(f'Initialization Time: {time() - t0}')
#     12
#     13         3         38.0     12.7      0.0      for iter in range(num_iter):
#     14         2         10.0      5.0      0.0          t0 = 0
#     15         2          8.0      4.0      0.0          if verbose > 0:
#     16                                                       print(f'Iteration {iter}:')
#     17                                                       t0 = time()
#     18
#     19         2       5526.0   2763.0      0.0          gram = D @ D.T
#     20         2     829856.0 414928.0      1.7          cov = D @ Y.T
#     21         6   44378226.0  7.4e+06     89.1          X = orthogonal_mp_gram(
#     22         2          7.0      3.5      0.0              Gram=gram,
#     23         2          6.0      3.0      0.0              Xy=cov,
#     24         2          6.0      3.0      0.0              n_nonzero_coefs=T_0,
#     25         2         10.0      5.0      0.0              copy_Gram=False,
#     26         2          3.0      1.5      0.0              copy_Xy=False
#     27         2         15.0      7.5      0.0          ).T # Transpose to match X shape
#     28         2          8.0      4.0      0.0          if verbose > 0:
#     29                                                       print(f'\tCoding Time: {time() - t0}')
#     30
#     31         2         31.0     15.5      0.0          t0 = time()
#     32         2          4.0      2.0      0.0          unused_atom = False
#     33         2     852096.0 426048.0      1.7          XD = X @ D
#     34                                                   # E_k_R = Y
#     35                                                   # E_k_R -= X @ D
#     36       602       2875.0      4.8      0.0          for i in range(k):
#     37       600      50374.0     84.0      0.1              x_i = X[:, i]
#     38                                                       # filter = (x_i != 0)
#     39       600     669421.0   1115.7      1.3              filter = np.flatnonzero(x_i)
#     40       600       8429.0     14.0      0.0              x_i_R = x_i[filter]
#     41       600       4779.0      8.0      0.0              if x_i_R.shape[0] == 0:
#     42         2          4.0      2.0      0.0                  unused_atom=True
#     43         2          3.0      1.5      0.0                  continue
#     44
#     45       598     100484.0    168.0      0.2              res = X[filter, i][:, np.newaxis] * D[i]
#     46       598     124085.0    207.5      0.2              XD[filter] -= res
#     47       598     142891.0    238.9      0.3              E_k_R = Y[filter] - XD[filter]
#     48                                                       # E_k_R[filter] += X[filter, i][:, np.newaxis] * D[i]
#     49
#     50       598    2206873.0   3690.4      4.4              U, S, Vh = LA.svd(E_k_R, full_matrices=False)
#     51                                                       # U, S, Vh = LA.svd(E_k_R[filter], full_matrices=False)
#     52
#     53       598      76759.0    128.4      0.2              X[filter, i] = U[:, 0] * S[0]
#     54       598      10572.0     17.7      0.0              D[i] = Vh[0]
#     55
#     56       598     211238.0    353.2      0.4              XD[filter] += X[filter, i][:, np.newaxis] * D[i]
#     57                                                       # E_k_R[filter] -= X[filter, i][:, np.newaxis] * D[i]
#     58
#     59         2         10.0      5.0      0.0          if verbose > 0:
#     60                                                       print(f'\tUpdate Time: {time() - t0}')
#     61                                                       print(f'\tUnused Atom: {unused_atom}')
#     62
#     63         2     104620.0  52310.0      0.2          loss[iter] = LA.norm(Y - XD, ord='fro')
#     64                                                   # loss[iter] = LA.norm(E_k_R, ord='fro')
#     65
#     66         1         10.0     10.0      0.0      return D, loss

# %% [markdown]
# ## Requires memory_profiler to be installed if you want to run the following code locally !!!

# %%
# pip install memory_profiler

# %%
# %load_ext memory_profiler

# %%
num_iter = 2
Y = data

# %% [markdown]
# ## Baseline

# %%
# %memit kSVD_baseline(Y = Y, \
               T_0 = 1, \
               k = 300, \
               num_iter = num_iter, \
                verbose=0, rng = rng)
# Out:
# peak memory: 356.08 MiB, increment: 135.01 MiB

# %% [markdown]
# ## Improved

# %%
# %memit kSVD_improved(Y = Y, \
               T_0 = 1, \
               k = 300, \
               num_iter = num_iter, \
              verbose=0, rng = rng)
# Out:
# peak memory: 360.68 MiB, increment: 137.00 MiB
