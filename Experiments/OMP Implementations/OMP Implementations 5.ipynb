# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"

import numpy as np
import sklearn

from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.datasets import make_regression
from sklearn.decomposition import SparseCoder, sparse_encode
from sklearn.linear_model import orthogonal_mp_gram

import scipy.linalg as LA
from scipy.sparse.linalg import lsqr, lsmr

# %%
eye = np.eye(3)

# %%
eye
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
eye[0:1]
# Out:
# array([[1., 0., 0.]])

# %%
eye[0:1].shape
# Out:
# (1, 3)

# %%
eye[0:1].T.shape
# Out:
# (3, 1)

# %%
eye[[0, 1]]
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.]])

# %% [markdown]
# # Solve

# %%
def OMP(Y, T_0, D, rng=42, debug=False):
    # loss = np.empty(num_iter)
    # rng = np.random.default_rng(rng)

    X = np.zeros((Y.shape[0], D.shape[0]))

    # gram = D @ D.T
    # cov = D @ Y.T
    # X = sparse_encode(Y, 
    #                   D, 
    #                   algorithm='omp', 
    #                   n_nonzero_coefs = T_0,
    #                   gram = gram,
    #                   cov = cov,
    #                   copy_cov=False)

    for i, y in enumerate(Y):
        I = []
        D_I = np.zeros((T_0, D.shape[1]))
        r = y
        gamma = 0

        for j in range(T_0):
            D_r = np.abs(D @ r)
            k = np.argmax(D_r)
            
            I.append(k)
            D_I[j] = D[k]
            
            # gamma, res, rank, s = LA.lstsq(D_I[:j+1].T, y, lapack_driver='gelsd')
            # gamma, istop, itn, res = lsmr(D_I[:j+1].T, y)[:4]
            gamma = np.linalg.solve(D_I[:j+1] @ D_I[:j+1].T, D_I[:j+1] @ y)
            if debug:
                print(gamma.shape)
                print(D_I[:j+1].T.shape)
                print(y.shape)
            r = y - D_I[:(j+1)].T @ gamma 
            if debug:
                print(np.sum(r * r))
                # print(res)

        X[i, I] = gamma
        
    return X

# %% [markdown]
# # Handwritten QR (Gram-Schmidt)

# %%
def OMP_2(Y, T_0, D, rng=42, debug=False):
    # loss = np.empty(num_iter)
    # rng = np.random.default_rng(rng)

    X = np.zeros((Y.shape[0], D.shape[0]))
    D_norm = np.linalg.norm(D, axis=1)

    for i, y in enumerate(Y):
        I = []
        D_I = np.zeros((T_0, D.shape[1]))
        r = y
        gamma = 0
        Q = np.empty((D.shape[1], T_0))
        R = np.empty((T_0, T_0))
        
        for j in range(T_0):
            D_r = np.abs(D @ r)
            k = np.argmax(D_r)
            
            I.append(k)
            D_I[j] = D[k]

            if j == 0:
                # Q, R = LA.qr(D[k][:, np.newaxis],
                #             overwrite_a = False,
                #             mode = 'economic')
                # D_k_norm = np.linalg.norm(D[k])
                D_k_norm = D_norm[k]
                R[0, 0] = D_k_norm
                Q[:, 0] = D[k] / D_k_norm
                
                if debug:
                    print(np.linalg.norm(D_k_norm))
                    print(Q[:, 0].T @ Q[:, 0])
                    print(R)

                gamma = (y @ Q[:, :j+1]) / D_k_norm
                
            else:
                # Q, R = LA.qr_insert(Q, R, D[k][:, np.newaxis], j, which='col') 
                dot = Q[:, :j].T @ D[k]
                R[0:j, j] = dot
                q_j = D[k] - Q[:, :j] @ dot

                q_j_norm = np.linalg.norm(q_j)
                R[j, j] = q_j_norm
                Q[:, j] = q_j / q_j_norm

                if debug:            
                    print(Q[:, :j+1].T.shape)
                    print(y.shape)
                gamma = LA.solve_triangular(R[:j+1, :j+1], 
                                        Q[:, :j+1].T @ y, 
                                        overwrite_b = True,
                                        check_finite = False)
                

            if debug:
                print(gamma.shape)
                print(D_I[:j+1].T.shape)
                print(y.shape)
            r = y - gamma @ D_I[:(j+1)]  
            if debug:
                print(np.sum(r * r))
                # print(res)

        X[i, I] = gamma
        
    return X

# %% [markdown]
# # Batched OMP

# %%
def OMP_3(Y, T_0, D, batch_size = 2, rng=42, debug=False):
    # loss = np.empty(num_iter)
    # rng = np.random.default_rng(rng)

    X = np.zeros((Y.shape[0], D.shape[0]))
    D_norm = np.linalg.norm(D, axis=1, keepdims=True)

    splits = np.arange(0, Y.shape[0], step=batch_size)
    Y_batches = np.split(Y, splits)[1:]
    
    for i, y in enumerate(Y_batches):
        if i == (len(Y_batches) - 1):
            batch_size = np.arange(splits[i], len(Y)).shape[0]
            if debug:
                print(f'batch_size = {batch_size}')
        I = np.empty((batch_size, T_0), dtype=np.int32)
        D_I = np.zeros((batch_size, T_0, D.shape[1]))
        r = y   # (batch_size, D.shape[1])
        gamma = 0
        Q = np.empty((batch_size, D.shape[1], T_0))
        R = np.empty((batch_size, T_0, T_0))
        
        for j in range(T_0):
            if debug:
                print(f'Batch {i}, Iteration {j}')
                print(f'r shape: {r.shape}')
            D_r = np.abs(r @ D.T)
            k = np.argmax(D_r, axis = 1)
            
            I[:, j] = k
            D_I[:, j] = D[k]

            if j == 0:
                D_k_norm = D_norm[k]
                R[:, 0, 0] = D_k_norm[:, 0]
                Q[:, :, 0] = D[k] / D_k_norm
                
                if debug:
                    print(D_k_norm)
                    print(np.sum(Q[:, :, 0] ** 2, axis = 1))
                    print(R[:, 0, 0])

                gamma = np.squeeze(y[:, np.newaxis] @ Q[:, :, :1], axis=1) 
                gamma /= D_k_norm
                
            else:
                if debug:
                    print(np.transpose(Q[:, :, :j], (0, 2, 1)).shape)
                    print(D[k][..., np.newaxis].shape)
                # dot = np.transpose(Q[:, :, :j], (0, 2, 1)) @ D[k][..., np.newaxis]
                dot = np.squeeze(D[k][:, np.newaxis] @ Q[:, :, :j], axis=1)
                
                # R[:, 0:j, j] = dot[0]
                R[:, 0:j, j] = dot
                
                # q_j = D[k] - (Q[:, :, :j] @ dot)[..., 0]
                q_j = D[k] - np.squeeze(Q[:, :, :j] @ dot[..., np.newaxis], axis = -1)
                
                # q_j_norm = np.linalg.norm(q_j)
                q_j_norm = np.linalg.norm(q_j, axis = 1)
                
                R[:, j, j] = q_j_norm
                # Q[:, :, j] = q_j / q_j_norm
                Q[:, :, j] = q_j / q_j_norm[:, np.newaxis]
                

                if debug:            
                    print(Q[:, :, :j+1].shape)
                    print(y.shape)
                Q_T_y = np.transpose(y[:, np.newaxis] @ Q[:, :, :j+1], (0, 2, 1))
                gamma = LA.solve_triangular(R[:, :j+1, :j+1], 
                                        Q_T_y, 
                                        overwrite_b = True,
                                        check_finite = False)
                if debug:
                    print(f'original gamma shape: {gamma.shape}')
                # gamma = np.transpose(gamma, (0, 2, 1))
                gamma = np.squeeze(gamma, axis=-1)
                

            if debug:
                print(gamma.shape)
                print(f'D_I shape: {D_I[:, :j+1].shape}')
                print(f'y shape: {y.shape}')
            # est = (np.transpose(D_I[:, :j+1], (0, 2, 1)) @ gamma[..., np.newaxis])[..., 0] 
            est = np.squeeze(gamma[:, np.newaxis] @ D_I[:, :j+1], axis=1)
            if debug:
                print(f'est shape: {est.shape}')
            r = y - est
            # if r.ndim > 2:
                # r = np.transpose(r, (0, 2, 1))
            if debug:
                print(r.shape)
            if debug:
                print(np.sum(r * r, axis = -1))
                # print(res)

        # X[i, I] = gamma
        if i == (len(Y_batches) - 1):
            if debug:
                # print(splits[i].dtype)
                # print(I.dtype)
                print(f'gamma: {gamma}')
                print(f'gamma shape: {gamma.shape}')
                print(f'k shape: {k.shape}')
                print(f'I shape: {I.shape}')
            # if T_0 == 1:
            #     X[np.arange(splits[i], len(Y)), I[:, 0]] = gamma[:, 0]
            # else:
            #     X[np.arange(splits[i], len(Y))[:, np.newaxis], I] = gamma[:, 0, :]
            X[np.arange(splits[i], len(Y))[:, np.newaxis], I] = gamma
            
        elif i == 0:
            X[np.arange(0, splits[1])[:, np.newaxis], I] = gamma
        else:
            X[np.arange(splits[i], splits[i+1])[:, np.newaxis], I] = gamma

        if debug:
            print()
    return X

# %%
def OMP_verif(code):
    print(code)
    I = np.nonzero(code)
    print(I)
    print(code[I])

# %%
X, y = make_regression(n_samples = 50, n_features = 20, n_targets = 2, noise=4, random_state=0)

# %%
X.shape
# Out:
# (50, 20)

# %%
y.shape
# Out:
# (50, 2)

# %%
b_numpy = OMP(y.T, 3, X.T, debug=True)
# Out:
# (1,)
# (50, 1)
# (50,)
# 2449425.071243986
# (2,)
# (50, 2)
# (50,)
# 1675390.9154018096
# (3,)
# (50, 3)
# (50,)
# 1347560.0488303776
# (1,)
# (50, 1)
# (50,)
# 1817892.1699581572
# (2,)
# (50, 2)
# (50,)
# 1455231.954008666
# (3,)
# (50, 3)
# (50,)
# 1157900.6749918351

# %%
OMP_verif(b_numpy)
# Out:
# [[  0.         132.14938371   0.           0.           0.
#     0.           0.           0.          70.15323381   0.
#     0.          98.72352887   0.           0.           0.
#     0.           0.           0.           0.           0.        ]
#  [  0.         136.86874232   0.           0.           0.
#     0.           0.           0.          75.95811465   0.
#     0.           0.           0.           0.           0.
#     0.          67.35538119   0.           0.           0.        ]]
# (array([0, 0, 0, 1, 1, 1]), array([ 1,  8, 11,  1,  8, 16]))
# [132.14938371  70.15323381  98.72352887 136.86874232  75.95811465
#   67.35538119]

# %%
b_scipy = OMP_2(y.T, 3, X.T, debug=True)
# Out:
# 7.633996503399395
# 1.0000000000000002
# [[ 7.6339965   3.7894417   1.49588522]
#  [ 3.7894417  67.05616075 -2.05742687]
#  [ 1.49588522 -2.05742687 65.66658662]]
# (1,)
# (50, 1)
# (50,)
# 2449425.0712439856
# (2, 50)
# (50,)
# (2,)
# (50, 2)
# (50,)
# 1675390.9154018096
# (3, 50)
# (50,)
# (3,)
# (50, 3)
# (50,)
# 1347560.0488303776
# 6.3385975871569675
# 1.0000000000000004
# [[ 6.33859759  3.7894417   1.49588522]
#  [ 3.7894417  67.05616075  2.05742687]
#  [ 1.49588522  2.05742687 65.66658662]]
# (1,)
# (50, 1)
# (50,)
# 1817892.1699581577
# (2, 50)
# (50,)
# (2,)
# (50, 2)
# (50,)
# 1455231.9540086659
# (3, 50)
# (50,)
# (3,)
# (50, 3)
# (50,)
# 1157900.6749918351

# %%
OMP_verif(b_scipy)
# Out:
# [[  0.         132.14938371   0.           0.           0.
#     0.           0.           0.          70.15323381   0.
#     0.          98.72352887   0.           0.           0.
#     0.           0.           0.           0.           0.        ]
#  [  0.         136.86874232   0.           0.           0.
#     0.           0.           0.          75.95811465   0.
#     0.           0.           0.           0.           0.
#     0.          67.35538119   0.           0.           0.        ]]
# (array([0, 0, 0, 1, 1, 1]), array([ 1,  8, 11,  1,  8, 16]))
# [132.14938371  70.15323381  98.72352887 136.86874232  75.95811465
#   67.35538119]

# %%
b_scipy2 = OMP_3(y.T, 3, X.T, batch_size = 2, debug=False)

# %%
OMP_verif(b_scipy2)
# Out:
# [[  0.         132.14938371   0.           0.           0.
#     0.           0.           0.          70.15323381   0.
#     0.          98.72352887   0.           0.           0.
#     0.           0.           0.           0.           0.        ]
#  [  0.         136.86874232   0.           0.           0.
#     0.           0.           0.          75.95811465   0.
#     0.           0.           0.           0.           0.
#     0.          67.35538119   0.           0.           0.        ]]
# (array([0, 0, 0, 1, 1, 1]), array([ 1,  8, 11,  1,  8, 16]))
# [132.14938371  70.15323381  98.72352887 136.86874232  75.95811465
#   67.35538119]

# %%
# b_scipy3 = OMP_4(y.T, 3, X.T, debug=True)

# %%
# OMP_verif(b_scipy3)

# %%
# b_scipy4 = OMP_5(y.T, 3, X.T, debug=True)

# %%
# OMP_verif(b_scipy4)

# %%
np.allclose(b_scipy[np.nonzero(b_scipy)], b_numpy[np.nonzero(b_numpy)])
# Out:
# True

# %%
np.allclose(b_scipy2[np.nonzero(b_scipy2)], b_numpy[np.nonzero(b_numpy)])
# Out:
# True

# %%
# np.allclose(b_scipy3[np.nonzero(b_scipy3)], b_numpy[np.nonzero(b_numpy)])

# %%
# np.allclose(b_scipy4[np.nonzero(b_scipy4)], b_numpy[np.nonzero(b_numpy)])

# %% [markdown]
# ## IT WORKS !!!

# %%
X, y = make_regression(n_samples = 50, n_features = 300, n_targets = 20_000, noise=4, random_state=0)

# %%
# %timeit OMP(y.T, 1, X.T)
# Out:
# 844 ms ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit OMP_2(y.T, 1, X.T)
# Out:
# 621 ms ± 65.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 1)
# Out:
# 1.03 s ± 87.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 2)
# Out:
# 519 ms ± 25 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 4)
# Out:
# 304 ms ± 6.19 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 8)
# Out:
# 180 ms ± 1.36 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 16)
# Out:
# 111 ms ± 2.79 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 32)
# Out:
# 83.4 ms ± 1.21 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit OMP_3(y.T, 1, X.T, batch_size = 50)
# Out:
# 67.9 ms ± 1.15 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit OMP_4(y.T, 1, X.T)

# %%
# %timeit OMP_5(y.T, 1, X.T)

# %%
# %load_ext line_profiler
from line_profiler import profile

# %%
np_OMP = profile(OMP)
# %lprun -f np_OMP np_OMP(y.T, 1, X.T)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 1.52091 s
# File: C:\Users\richa\AppData\Local\Temp\ipykernel_27324\3367727764.py
# Function: OMP at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def OMP(Y, T_0, D, rng=42, debug=False):
#      2                                               # loss = np.empty(num_iter)
#      3                                               # rng = np.random.default_rng(rng)
#      4
#      5         1        410.0    410.0      0.0      X = np.zeros((Y.shape[0], D.shape[0]))
#      6
#      7                                               # gram = D @ D.T
#      8                                               # cov = D @ Y.T
#      9                                               # X = sparse_encode(Y,
#     10                                               #                   D,
#     11                                               #                   algorithm='omp',
#     12                                               #                   n_nonzero_coefs = T_0,
#     13                                               #                   gram = gram,
#     14                                               #                   cov = cov,
#     15                                               #                   copy_cov=False)
#     16
#     17     20001     189296.0      9.5      1.2      for i, y in enumerate(Y):
#     18     20000      56833.0      2.8      0.4          I = []
#     19     20000     388601.0     19.4      2.6          D_I = np.zeros((T_0, D.shape[1]))
#     20     20000      47863.0      2.4      0.3          r = y
#     21     20000      43895.0      2.2      0.3          gamma = 0
#     22
#     23     40000     283728.0      7.1      1.9          for j in range(T_0):
#     24     20000    1758523.0     87.9     11.6              D_r = np.abs(D @ r)
#     25     20000    1493195.0     74.7      9.8              k = np.argmax(D_r)
#     26
#     27     20000     128001.0      6.4      0.8              I.append(k)
#     28     20000     382960.0     19.1      2.5              D_I[j] = D[k]
#     29
#     30                                                       # gamma, res, rank, s = LA.lstsq(D_I[:j+1].T, y, lapack_driver='gelsd')
#     31                                                       # gamma, istop, itn, res = lsmr(D_I[:j+1].T, y)[:4]
#     32     20000    7990850.0    399.5     52.5              gamma = np.linalg.solve(D_I[:j+1] @ D_I[:j+1].T, D_I[:j+1] @ y)
#     33     20000      41593.0      2.1      0.3              if debug:
#     34                                                           print(gamma.shape)
#     35                                                           print(D_I[:j+1].T.shape)
#     36                                                           print(y.shape)
#     37     20000    1019145.0     51.0      6.7              r = y - D_I[:(j+1)].T @ gamma
#     38     20000      54356.0      2.7      0.4              if debug:
#     39                                                           print(np.sum(r * r))
#     40                                                           # print(res)
#     41
#     42     20000    1329896.0     66.5      8.7          X[i, I] = gamma
#     43
#     44         1          1.0      1.0      0.0      return X

# %%
sci_OMP = profile(OMP_2)
# %lprun -f sci_OMP sci_OMP(y.T, 1, X.T)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.815814 s
# File: C:\Users\richa\AppData\Local\Temp\ipykernel_27324\3318475742.py
# Function: OMP_2 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def OMP_2(Y, T_0, D, rng=42, debug=False):
#      2                                               # loss = np.empty(num_iter)
#      3                                               # rng = np.random.default_rng(rng)
#      4
#      5         1        385.0    385.0      0.0      X = np.zeros((Y.shape[0], D.shape[0]))
#      6         1       1417.0   1417.0      0.0      D_norm = np.linalg.norm(D, axis=1)
#      7
#      8     20001     161813.0      8.1      2.0      for i, y in enumerate(Y):
#      9     20000      50686.0      2.5      0.6          I = []
#     10     20000     321249.0     16.1      3.9          D_I = np.zeros((T_0, D.shape[1]))
#     11     20000      42870.0      2.1      0.5          r = y
#     12     20000      44298.0      2.2      0.5          gamma = 0
#     13     20000     200435.0     10.0      2.5          Q = np.empty((D.shape[1], T_0))
#     14     20000     137753.0      6.9      1.7          R = np.empty((T_0, T_0))
#     15
#     16     40000     243682.0      6.1      3.0          for j in range(T_0):
#     17     20000    1557266.0     77.9     19.1              D_r = np.abs(D @ r)
#     18     20000    1385086.0     69.3     17.0              k = np.argmax(D_r)
#     19
#     20     20000     116886.0      5.8      1.4              I.append(k)
#     21     20000     327540.0     16.4      4.0              D_I[j] = D[k]
#     22
#     23     20000      65503.0      3.3      0.8              if j == 0:
#     24                                                           # Q, R = LA.qr(D[k][:, np.newaxis],
#     25                                                           #             overwrite_a = False,
#     26                                                           #             mode = 'economic')
#     27                                                           # D_k_norm = np.linalg.norm(D[k])
#     28     20000      80313.0      4.0      1.0                  D_k_norm = D_norm[k]
#     29     20000      72884.0      3.6      0.9                  R[0, 0] = D_k_norm
#     30     20000     619775.0     31.0      7.6                  Q[:, 0] = D[k] / D_k_norm
#     31
#     32     20000      34723.0      1.7      0.4                  if debug:
#     33                                                               print(np.linalg.norm(D_k_norm))
#     34                                                               print(Q[:, 0].T @ Q[:, 0])
#     35                                                               print(R)
#     36
#     37     20000     943625.0     47.2     11.6                  gamma = (y @ Q[:, :j+1]) / D_k_norm
#     38
#     39                                                       else:
#     40                                                           # Q, R = LA.qr_insert(Q, R, D[k][:, np.newaxis], j, which='col')
#     41                                                           dot = Q[:, :j].T @ D[k]
#     42                                                           R[0:j, j] = dot
#     43                                                           q_j = D[k] - Q[:, :j] @ dot
#     44
#     45                                                           q_j_norm = np.linalg.norm(q_j)
#     46                                                           R[j, j] = q_j_norm
#     47                                                           Q[:, j] = q_j / q_j_norm
#     48
#     49                                                           if debug:
#     50                                                               print(Q[:, :j+1].T.shape)
#     51                                                               print(y.shape)
#     52                                                           gamma = LA.solve_triangular(R[:j+1, :j+1],
#     53                                                                                   Q[:, :j+1].T @ y,
#     54                                                                                   overwrite_b = True,
#     55                                                                                   check_finite = False)
#     56
#     57
#     58     20000      36039.0      1.8      0.4              if debug:
#     59                                                           print(gamma.shape)
#     60                                                           print(D_I[:j+1].T.shape)
#     61                                                           print(y.shape)
#     62     20000     676773.0     33.8      8.3              r = y - gamma @ D_I[:(j+1)]
#     63     20000      47250.0      2.4      0.6              if debug:
#     64                                                           print(np.sum(r * r))
#     65                                                           # print(res)
#     66
#     67     20000     989884.0     49.5     12.1          X[i, I] = gamma
#     68
#     69         1          2.0      2.0      0.0      return X

# %%
sci_OMP2 = profile(OMP_3)
# %lprun -f sci_OMP2 sci_OMP2(y.T, 1, X.T)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.742623 s
# File: C:\Users\richa\AppData\Local\Temp\ipykernel_27324\3497261423.py
# Function: OMP_3 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def OMP_3(Y, T_0, D, batch_size = 2, rng=42, debug=False):
#      2                                               # loss = np.empty(num_iter)
#      3                                               # rng = np.random.default_rng(rng)
#      4
#      5         1        396.0    396.0      0.0      X = np.zeros((Y.shape[0], D.shape[0]))
#      6         1       1000.0   1000.0      0.0      D_norm = np.linalg.norm(D, axis=1, keepdims=True)
#      7
#      8         1        182.0    182.0      0.0      splits = np.arange(0, Y.shape[0], step=batch_size)
#      9         1     407143.0 407143.0      5.5      Y_batches = np.split(Y, splits)[1:]
#     10
#     11     10001      65222.0      6.5      0.9      for i, y in enumerate(Y_batches):
#     12     10000     151211.0     15.1      2.0          I = np.empty((batch_size, T_0), dtype=np.int32)
#     13     10000     124519.0     12.5      1.7          D_I = np.zeros((batch_size, T_0, D.shape[1]))
#     14     10000      22354.0      2.2      0.3          r = y   # (batch_size, D.shape[1])
#     15     10000      34645.0      3.5      0.5          gamma = 0
#     16     10000     100503.0     10.1      1.4          Q = np.empty((batch_size, D.shape[1], T_0))
#     17     10000      73572.0      7.4      1.0          R = np.empty((batch_size, T_0, T_0))
#     18
#     19     20000     132606.0      6.6      1.8          for j in range(T_0):
#     20     10000      19030.0      1.9      0.3              if debug:
#     21                                                           print(f'Batch {i}, Iteration {j}')
#     22                                                           print(f'r shape: {r.shape}')
#     23     10000    1119208.0    111.9     15.1              D_r = np.abs(r @ D.T)
#     24     10000     720185.0     72.0      9.7              k = np.argmax(D_r, axis = 1)
#     25
#     26     10000     182563.0     18.3      2.5              I[:, j] = k
#     27     10000     448685.0     44.9      6.0              D_I[:, j] = D[k]
#     28
#     29     10000      36523.0      3.7      0.5              if j == 0:
#     30     10000     224322.0     22.4      3.0                  D_k_norm = D_norm[k]
#     31     10000     136776.0     13.7      1.8                  R[:, 0, 0] = D_k_norm[:, 0]
#     32     10000     608476.0     60.8      8.2                  Q[:, :, 0] = D[k] / D_k_norm
#     33
#     34     10000      19558.0      2.0      0.3                  if debug:
#     35                                                               print(D_k_norm)
#     36                                                               print(np.sum(Q[:, :, 0] ** 2, axis = 1))
#     37                                                               print(R[:, 0, 0])
#     38
#     39     10000     738312.0     73.8      9.9                  gamma = np.squeeze(y[:, np.newaxis] @ Q[:, :, :1], axis=1)
#     40     10000     114341.0     11.4      1.5                  gamma /= D_k_norm
#     41
#     42                                                       else:
#     43                                                           if debug:
#     44                                                               print(np.transpose(Q[:, :, :j], (0, 2, 1)).shape)
#     45                                                               print(D[k][..., np.newaxis].shape)
#     46                                                           # dot = np.transpose(Q[:, :, :j], (0, 2, 1)) @ D[k][..., np.newaxis]
#     47                                                           dot = np.squeeze(D[k][:, np.newaxis] @ Q[:, :, :j], axis=1)
#     48
#     49                                                           # R[:, 0:j, j] = dot[0]
#     50                                                           R[:, 0:j, j] = dot
#     51
#     52                                                           # q_j = D[k] - (Q[:, :, :j] @ dot)[..., 0]
#     53                                                           q_j = D[k] - np.squeeze(Q[:, :, :j] @ dot[..., np.newaxis], axis = -1)
#     54
#     55                                                           # q_j_norm = np.linalg.norm(q_j)
#     56                                                           q_j_norm = np.linalg.norm(q_j, axis = 1)
#     57
#     58                                                           R[:, j, j] = q_j_norm
#     59                                                           # Q[:, :, j] = q_j / q_j_norm
#     60                                                           Q[:, :, j] = q_j / q_j_norm[:, np.newaxis]
#     61
#     62
#     63                                                           if debug:
#     64                                                               print(Q[:, :, :j+1].shape)
#     65                                                               print(y.shape)
#     66                                                           Q_T_y = np.transpose(y[:, np.newaxis] @ Q[:, :, :j+1], (0, 2, 1))
#     67                                                           gamma = LA.solve_triangular(R[:, :j+1, :j+1],
#     68                                                                                   Q_T_y,
#     69                                                                                   overwrite_b = True,
#     70                                                                                   check_finite = False)
#     71                                                           if debug:
#     72                                                               print(f'original gamma shape: {gamma.shape}')
#     73                                                           # gamma = np.transpose(gamma, (0, 2, 1))
#     74                                                           gamma = np.squeeze(gamma, axis=-1)
#     75
#     76
#     77     10000      18826.0      1.9      0.3              if debug:
#     78                                                           print(gamma.shape)
#     79                                                           print(f'D_I shape: {D_I[:, :j+1].shape}')
#     80                                                           print(f'y shape: {y.shape}')
#     81                                                       # est = (np.transpose(D_I[:, :j+1], (0, 2, 1)) @ gamma[..., np.newaxis])[..., 0]
#     82     10000     626118.0     62.6      8.4              est = np.squeeze(gamma[:, np.newaxis] @ D_I[:, :j+1], axis=1)
#     83     10000      18078.0      1.8      0.2              if debug:
#     84                                                           print(f'est shape: {est.shape}')
#     85     10000     269519.0     27.0      3.6              r = y - est
#     86                                                       # if r.ndim > 2:
#     87                                                           # r = np.transpose(r, (0, 2, 1))
#     88     10000      18074.0      1.8      0.2              if debug:
#     89                                                           print(r.shape)
#     90     10000      22720.0      2.3      0.3              if debug:
#     91                                                           print(np.sum(r * r, axis = -1))
#     92                                                           # print(res)
#     93
#     94                                                   # X[i, I] = gamma
#     95     10000      86881.0      8.7      1.2          if i == (len(Y_batches) - 1):
#     96         1          2.0      2.0      0.0              if debug:
#     97                                                           # print(splits[i].dtype)
#     98                                                           # print(I.dtype)
#     99                                                           print(f'gamma: {gamma}')
#    100                                                           print(f'gamma shape: {gamma.shape}')
#    101                                                           print(f'k shape: {k.shape}')
#    102                                                           print(f'I shape: {I.shape}')
#    103                                                       # if T_0 == 1:
#    104                                                       #     X[np.arange(splits[i], len(Y)), I[:, 0]] = gamma[:, 0]
#    105                                                       # else:
#    106                                                       #     X[np.arange(splits[i], len(Y))[:, np.newaxis], I] = gamma[:, 0, :]
#    107         1        105.0    105.0      0.0              X[np.arange(splits[i], len(Y))[:, np.newaxis], I] = gamma
#    108
#    109      9999      24270.0      2.4      0.3          elif i == 0:
#    110         1        185.0    185.0      0.0              X[np.arange(0, splits[1])[:, np.newaxis], I] = gamma
#    111                                                   else:
#    112      9998     835047.0     83.5     11.2              X[np.arange(splits[i], splits[i+1])[:, np.newaxis], I] = gamma
#    113
#    114     10000      25075.0      2.5      0.3          if debug:
#    115                                                       print()
#    116         1          1.0      1.0      0.0      return X

# %%
# %lprun -f sci_OMP2 sci_OMP2(y.T, 1, X.T, batch_size = 50)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0747306 s
# File: C:\Users\richa\AppData\Local\Temp\ipykernel_27324\3497261423.py
# Function: OMP_3 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def OMP_3(Y, T_0, D, batch_size = 2, rng=42, debug=False):
#      2                                               # loss = np.empty(num_iter)
#      3                                               # rng = np.random.default_rng(rng)
#      4
#      5         1        386.0    386.0      0.1      X = np.zeros((Y.shape[0], D.shape[0]))
#      6         1        986.0    986.0      0.1      D_norm = np.linalg.norm(D, axis=1, keepdims=True)
#      7
#      8         1        102.0    102.0      0.0      splits = np.arange(0, Y.shape[0], step=batch_size)
#      9         1      18271.0  18271.0      2.4      Y_batches = np.split(Y, splits)[1:]
#     10
#     11       401       3014.0      7.5      0.4      for i, y in enumerate(Y_batches):
#     12       400       7856.0     19.6      1.1          I = np.empty((batch_size, T_0), dtype=np.int32)
#     13       400      12356.0     30.9      1.7          D_I = np.zeros((batch_size, T_0, D.shape[1]))
#     14       400       1508.0      3.8      0.2          r = y   # (batch_size, D.shape[1])
#     15       400       1580.0      4.0      0.2          gamma = 0
#     16       400       6543.0     16.4      0.9          Q = np.empty((batch_size, D.shape[1], T_0))
#     17       400       3233.0      8.1      0.4          R = np.empty((batch_size, T_0, T_0))
#     18
#     19       800       5919.0      7.4      0.8          for j in range(T_0):
#     20       400        759.0      1.9      0.1              if debug:
#     21                                                           print(f'Batch {i}, Iteration {j}')
#     22                                                           print(f'r shape: {r.shape}')
#     23       400     248187.0    620.5     33.2              D_r = np.abs(r @ D.T)
#     24       400      65364.0    163.4      8.7              k = np.argmax(D_r, axis = 1)
#     25
#     26       400       9028.0     22.6      1.2              I[:, j] = k
#     27       400      38164.0     95.4      5.1              D_I[:, j] = D[k]
#     28
#     29       400       1689.0      4.2      0.2              if j == 0:
#     30       400      11934.0     29.8      1.6                  D_k_norm = D_norm[k]
#     31       400       6491.0     16.2      0.9                  R[:, 0, 0] = D_k_norm[:, 0]
#     32       400      57686.0    144.2      7.7                  Q[:, :, 0] = D[k] / D_k_norm
#     33
#     34       400        904.0      2.3      0.1                  if debug:
#     35                                                               print(D_k_norm)
#     36                                                               print(np.sum(Q[:, :, 0] ** 2, axis = 1))
#     37                                                               print(R[:, 0, 0])
#     38
#     39       400      50208.0    125.5      6.7                  gamma = np.squeeze(y[:, np.newaxis] @ Q[:, :, :1], axis=1)
#     40       400       6037.0     15.1      0.8                  gamma /= D_k_norm
#     41
#     42                                                       else:
#     43                                                           if debug:
#     44                                                               print(np.transpose(Q[:, :, :j], (0, 2, 1)).shape)
#     45                                                               print(D[k][..., np.newaxis].shape)
#     46                                                           # dot = np.transpose(Q[:, :, :j], (0, 2, 1)) @ D[k][..., np.newaxis]
#     47                                                           dot = np.squeeze(D[k][:, np.newaxis] @ Q[:, :, :j], axis=1)
#     48
#     49                                                           # R[:, 0:j, j] = dot[0]
#     50                                                           R[:, 0:j, j] = dot
#     51
#     52                                                           # q_j = D[k] - (Q[:, :, :j] @ dot)[..., 0]
#     53                                                           q_j = D[k] - np.squeeze(Q[:, :, :j] @ dot[..., np.newaxis], axis = -1)
#     54
#     55                                                           # q_j_norm = np.linalg.norm(q_j)
#     56                                                           q_j_norm = np.linalg.norm(q_j, axis = 1)
#     57
#     58                                                           R[:, j, j] = q_j_norm
#     59                                                           # Q[:, :, j] = q_j / q_j_norm
#     60                                                           Q[:, :, j] = q_j / q_j_norm[:, np.newaxis]
#     61
#     62
#     63                                                           if debug:
#     64                                                               print(Q[:, :, :j+1].shape)
#     65                                                               print(y.shape)
#     66                                                           Q_T_y = np.transpose(y[:, np.newaxis] @ Q[:, :, :j+1], (0, 2, 1))
#     67                                                           gamma = LA.solve_triangular(R[:, :j+1, :j+1],
#     68                                                                                   Q_T_y,
#     69                                                                                   overwrite_b = True,
#     70                                                                                   check_finite = False)
#     71                                                           if debug:
#     72                                                               print(f'original gamma shape: {gamma.shape}')
#     73                                                           # gamma = np.transpose(gamma, (0, 2, 1))
#     74                                                           gamma = np.squeeze(gamma, axis=-1)
#     75
#     76
#     77       400        832.0      2.1      0.1              if debug:
#     78                                                           print(gamma.shape)
#     79                                                           print(f'D_I shape: {D_I[:, :j+1].shape}')
#     80                                                           print(f'y shape: {y.shape}')
#     81                                                       # est = (np.transpose(D_I[:, :j+1], (0, 2, 1)) @ gamma[..., np.newaxis])[..., 0]
#     82       400      50883.0    127.2      6.8              est = np.squeeze(gamma[:, np.newaxis] @ D_I[:, :j+1], axis=1)
#     83       400        727.0      1.8      0.1              if debug:
#     84                                                           print(f'est shape: {est.shape}')
#     85       400      27523.0     68.8      3.7              r = y - est
#     86                                                       # if r.ndim > 2:
#     87                                                           # r = np.transpose(r, (0, 2, 1))
#     88       400        796.0      2.0      0.1              if debug:
#     89                                                           print(r.shape)
#     90       400       1228.0      3.1      0.2              if debug:
#     91                                                           print(np.sum(r * r, axis = -1))
#     92                                                           # print(res)
#     93
#     94                                                   # X[i, I] = gamma
#     95       400       4350.0     10.9      0.6          if i == (len(Y_batches) - 1):
#     96         1          2.0      2.0      0.0              if debug:
#     97                                                           # print(splits[i].dtype)
#     98                                                           # print(I.dtype)
#     99                                                           print(f'gamma: {gamma}')
#    100                                                           print(f'gamma shape: {gamma.shape}')
#    101                                                           print(f'k shape: {k.shape}')
#    102                                                           print(f'I shape: {I.shape}')
#    103                                                       # if T_0 == 1:
#    104                                                       #     X[np.arange(splits[i], len(Y)), I[:, 0]] = gamma[:, 0]
#    105                                                       # else:
#    106                                                       #     X[np.arange(splits[i], len(Y))[:, np.newaxis], I] = gamma[:, 0, :]
#    107         1        370.0    370.0      0.0              X[np.arange(splits[i], len(Y))[:, np.newaxis], I] = gamma
#    108
#    109       399       1008.0      2.5      0.1          elif i == 0:
#    110         1        669.0    669.0      0.1              X[np.arange(0, splits[1])[:, np.newaxis], I] = gamma
#    111                                                   else:
#    112       398      99607.0    250.3     13.3              X[np.arange(splits[i], splits[i+1])[:, np.newaxis], I] = gamma
#    113
#    114       400       1103.0      2.8      0.1          if debug:
#    115                                                       print()
#    116         1          3.0      3.0      0.0      return X

# %%
# sci_OMP3 = profile(OMP_4)
# %lprun -f sci_OMP3 sci_OMP3(y.T, 1, X.T)

# %%
# sci_OMP4 = profile(OMP_5)
# %lprun -f sci_OMP4 sci_OMP4(y.T, 1, X.T)

# %%
X1, y1 = make_regression(n_samples = 50, n_features = 20, n_targets = 100, noise=4, random_state=0)

# %%
X2, y2 = make_regression(n_samples = 50, n_features = 20, n_targets = 100, noise=4, random_state=0)

# %%
X1.shape
# Out:
# (50, 20)

# %%
X2.shape
# Out:
# (50, 20)

# %%
X_12 = np.stack([X1, X2], axis=0)

# %%
X_12.shape
# Out:
# (2, 50, 20)

# %%
y_12 = np.stack([y1, y2], axis=0)

# %%
LA.lstsq(X_12, y_12)[0].shape
# Out:
# (2, 20, 100)

# %%
np.eye(3)[0][:, np.newaxis].shape
# Out:
# (3, 1)
