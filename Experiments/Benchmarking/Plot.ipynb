# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("omp_benchmark_all.csv")
functions = df["function"].unique()

# %%
functions
# Out:
# <StringArray>
# [                      'OMP_serial',                    'OMP_numba_jit',
#                    'OMP_numba_njit', 'OMP_numba_njit_parallel_pbatches',
#                       'Approx_V1_1',                  'Numba_Approx_V0',
#                   'Numba_Approx_V1']
# Length: 7, dtype: str

# %%
plt.figure()
for fn in functions:
    subset_fn = df[df["function"] == fn]
    threads_list = sorted(subset_fn["threads"].unique())
    # sub = subset_fn[subset_fn["threads"] == t]
    sub = subset_fn
    plt.plot(
        sub["batch_size"],
        sub["time_sec"],
        marker='o',
        label=f"{fn}"
    )
    plt.xscale("log", base=2)
    plt.yscale("log")
    plt.xlabel("Batch Size")
    plt.ylabel("Time (s)")
    plt.title('OMP Showdown')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("omp_benchmark_all_thread_limit.csv")
functions = df["function"].unique()

# %%
functions
# Out:
# <StringArray>
# [                      'OMP_serial',                    'OMP_numba_jit',
#                    'OMP_numba_njit', 'OMP_numba_njit_parallel_pbatches',
#                       'Approx_V1_1',                  'Numba_Approx_V0',
#                   'Numba_Approx_V1']
# Length: 7, dtype: str

# %%
plt.figure()
for fn in functions:
    subset_fn = df[df["function"] == fn]
    threads_list = sorted(subset_fn["threads"].unique())
    # sub = subset_fn[subset_fn["threads"] == t]
    sub = subset_fn
    plt.plot(
        sub["batch_size"],
        sub["time_sec"],
        marker='o',
        label=f"{fn}"
    )
    plt.xscale("log", base=2)
    plt.yscale("log")
    plt.xlabel("Batch Size")
    plt.ylabel("Time (s)")
    plt.title('OMP Showdown with Thread Limit')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("omp_benchmark_all_thread_limit_FP32.csv")
functions = df["function"].unique()

# %%
functions
# Out:
# <StringArray>
# ['OMP_serial', 'Approx_V1_1', 'Numba_Approx_V0', 'Numba_Approx_V1']
# Length: 4, dtype: str

# %%
plt.figure()
for fn in functions:
    subset_fn = df[df["function"] == fn]
    threads_list = sorted(subset_fn["threads"].unique())
    # sub = subset_fn[subset_fn["threads"] == t]
    sub = subset_fn
    plt.plot(
        sub["batch_size"],
        sub["time_sec"],
        marker='o',
        label=f"{fn}"
    )
    plt.xscale("log", base=2)
    plt.yscale("log")
    plt.xlabel("Batch Size")
    plt.ylabel("Time (s)")
    plt.title('OMP Showdown with Thread Limit and FP32')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("omp_benchmark_parallel.csv")
functions = df["function"].unique()

# %%
functions
# Out:
# <StringArray>
# [         'OMP_numba_njit_parallel', 'OMP_numba_njit_parallel_pbatches',
#                       'Approx_V1_1',                  'Numba_Approx_V0',
#                   'Numba_Approx_V1',             'Para_Numba_Approx_V0']
# Length: 6, dtype: str

# %%
plt.figure()
for fn in functions:
    subset_fn = df[df["function"] == fn]
    threads_list = sorted(subset_fn["threads"].unique())
    # sub = subset_fn[subset_fn["threads"] == t]
    sub = subset_fn
    plt.plot(
        sub["batch_size"],
        sub["time_sec"],
        marker='o',
        label=f"{fn}"
    )
    plt.xscale("log", base=2)
    plt.yscale("log")
    plt.xlabel("Batch Size")
    plt.ylabel("Time (s)")
    plt.title('OMP Showdown Parallel')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("thread_scaling.csv")
functions = df["function"].unique()

# %%
functions
# Out:
# <StringArray>
# ['OMP_numba_njit_parallel_pbatches',                      'Approx_V1_1',
#                   'Numba_Approx_V2',             'Para_Numba_Approx_V1']
# Length: 4, dtype: str

# %%
for fn in functions:
    plt.figure()
    
    subset_fn = df[df["function"] == fn]
    threads_list = sorted(subset_fn["threads"].unique())

    for t in threads_list:
        sub = subset_fn[subset_fn["threads"] == t]
        # sub = subset_fn
        plt.plot(
            sub["batch_size"],
            sub["time_sec"],
            marker='o',
            label=f"{t} threads"
        )
    plt.xscale("log", base=2)
    plt.yscale("log")
    plt.xlabel("Batch Size")
    plt.ylabel("Time (s)")
    plt.title(fn + ' Thread Scaling')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
plt.show()
