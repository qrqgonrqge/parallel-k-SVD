# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"

import numpy as np
import timeit
import csv
import numba
from numba import njit, prange, get_num_threads, get_thread_id, set_num_threads
from sklearn.datasets import make_regression

import sys

# %%
# numba.set_num_threads(get_num_threads() // 2)

# %%
current_dir = os.getcwd()
# current_dir

# %%
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(current_dir), '../')))

# %%
# os.path.dirname(current_dir)

# %%
# sys.path

# %%
# -----------------------------
# IMPORT YOUR FUNCTIONS
# -----------------------------
from Experiments.Numba.OMP_Implementations.OMP_numba_parallel import (
    OMP_serial,
    OMP_numba_serial,
    OMP_numba_jit,
    OMP_numba_njit,
    OMP_numba_njit_parallel,
    OMP_numba_njit_parallel_pbatches,
)

# %%
# import importlib
from Implementations.AK_SVD.Approx_V1_1 import OMP as OMP_A_V1_1
from Implementations.AK_SVD.Numba_Approx_V0 import OMP as OMP_NA_V0
from Implementations.AK_SVD.Numba_Approx_V1 import OMP as OMP_NA_V1
from Implementations.AK_SVD.Para_Numba_Approx_V0 import OMP as OMP_PNA_V0

# %%
# -----------------------------
# DATA SETUP
# -----------------------------
D, y = make_regression(
    n_samples=50,
    n_features=300,
    n_targets=20000,
    noise=4,
    random_state=0
)

Y = y.T.astype(np.float64)
D = D.T.astype(np.float64)

n_samples = Y.shape[0]

# %%
# -----------------------------
# PARAMS
# -----------------------------
T_0 = 1
N = 10  # timeit runs

functions = [
    # ("OMP_serial", OMP_serial),
    # ("OMP_numba_serial", OMP_numba_serial),
    # ("OMP_numba_jit", OMP_numba_jit),
    # ("OMP_numba_njit", OMP_numba_njit),
    ("OMP_numba_njit_parallel", OMP_numba_njit_parallel),
    ("OMP_numba_njit_parallel_pbatches", OMP_numba_njit_parallel_pbatches),
    
    ("Approx_V1_1", OMP_A_V1_1),
    ("Numba_Approx_V0", OMP_NA_V0),
    ("Numba_Approx_V1", OMP_NA_V1),   
    ("Para_Numba_Approx_V0", OMP_PNA_V0),   
]

max_threads = numba.get_num_threads()

thread_list = [6]
batch_sizes = [2**i for i in range(1, int(np.log2(n_samples/16)) + 1)]
batch_sizes = [b for b in batch_sizes if b <= n_samples]

print("Threads:", thread_list)
print("Batch sizes:", batch_sizes)
# Out:
# Threads: [6]
# Batch sizes: [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
# -----------------------------
# WARMUP (compile all functions)
# -----------------------------
for name, fn in functions:
    print(name)
    try:
        fn(Y, T_0, D, batch_size=2, float_dtype=np.float64)
    except Exception as e:
        print(e)
        try:
            fn(Y, T_0, D, batch_size=2)
        except Exception as f:
            print(f)
        print()
# Out:
# OMP_numba_njit_parallel
# some keyword arguments unexpected
# C:\Users\richa\Jupyter Notebooks\CSE 392 - Parallel Algorithms\kSVD\Experiments\Numba\OMP_Implementations\OMP_numba_parallel.py:809: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   dot = Dk_new[b] @ Q[b, :, :j]
# OMP_numba_njit_parallel_pbatches
# some keyword arguments unexpected
# C:\Users\richa\Jupyter Notebooks\CSE 392 - Parallel Algorithms\kSVD\Experiments\Numba\OMP_Implementations\OMP_numba_parallel.py:1039: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   dot = Dk_new[b] @ Q[b, :, :j]
# Approx_V1_1
# Numba_Approx_V0
# Numba_Approx_V1
# Para_Numba_Approx_V0

# %%
# -----------------------------
# BENCHMARK
# -----------------------------
results = []

for name, fn in functions:
    print(f"\n--- {name} ---")
    
    for n_threads in thread_list:
        set_num_threads(n_threads)
        
        for batch_size in batch_sizes:
            # define callable for timeit
            stmt = lambda: fn(Y, T_0, D, batch_size=batch_size)
            stmt2 = lambda: fn(Y, T_0, D, batch_size=batch_size, float_dtype=np.float64)
            
            
            try:
                stmt2()
            except:
                try:
                    stmt()
                except:
                    print(f"FAIL: {name}, threads={n_threads}, batch={batch_size}")
                    continue
            try:
                t = timeit.timeit(stmt2, number=N) / N
            except Exception as e:
                try:
                    t = timeit.timeit(stmt, number=N) / N               
                except:
                    print(f"FAIL: {name}, threads={n_threads}, batch={batch_size}")
                    continue

            print(f"{name} | threads={n_threads} | batch={batch_size} | {t:.6f}s")

            results.append((name, n_threads, batch_size, t))
# Out:
# --- OMP_numba_njit_parallel ---
# OMP_numba_njit_parallel | threads=6 | batch=2 | 3.026701s
# OMP_numba_njit_parallel | threads=6 | batch=4 | 1.923596s
# OMP_numba_njit_parallel | threads=6 | batch=8 | 1.373159s
# OMP_numba_njit_parallel | threads=6 | batch=16 | 1.072330s
# OMP_numba_njit_parallel | threads=6 | batch=32 | 0.926909s
# OMP_numba_njit_parallel | threads=6 | batch=64 | 0.856984s
# OMP_numba_njit_parallel | threads=6 | batch=128 | 0.827740s
# OMP_numba_njit_parallel | threads=6 | batch=256 | 0.800139s
# OMP_numba_njit_parallel | threads=6 | batch=512 | 0.850379s
# OMP_numba_njit_parallel | threads=6 | batch=1024 | 0.823584s
#
# --- OMP_numba_njit_parallel_pbatches ---
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=2 | 0.079791s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=4 | 0.079446s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=8 | 0.070226s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=16 | 0.065725s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=32 | 0.067380s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=64 | 0.064772s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=128 | 0.063175s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=256 | 0.071683s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=512 | 0.108184s
# OMP_numba_njit_parallel_pbatches | threads=6 | batch=1024 | 0.115777s
#
# --- Approx_V1_1 ---
# Approx_V1_1 | threads=6 | batch=2 | 0.784728s
# Approx_V1_1 | threads=6 | batch=4 | 0.431792s
# Approx_V1_1 | threads=6 | batch=8 | 0.241030s
# Approx_V1_1 | threads=6 | batch=16 | 0.138587s
# Approx_V1_1 | threads=6 | batch=32 | 0.085354s
# Approx_V1_1 | threads=6 | batch=64 | 0.062928s
# Approx_V1_1 | threads=6 | batch=128 | 0.052715s
# Approx_V1_1 | threads=6 | batch=256 | 0.040328s
# Approx_V1_1 | threads=6 | batch=512 | 0.064289s
# Approx_V1_1 | threads=6 | batch=1024 | 0.059171s
#
# --- Numba_Approx_V0 ---
# Numba_Approx_V0 | threads=6 | batch=2 | 0.092335s
# Numba_Approx_V0 | threads=6 | batch=4 | 0.076178s
# Numba_Approx_V0 | threads=6 | batch=8 | 0.064899s
# Numba_Approx_V0 | threads=6 | batch=16 | 0.054745s
# Numba_Approx_V0 | threads=6 | batch=32 | 0.050877s
# Numba_Approx_V0 | threads=6 | batch=64 | 0.048905s
# Numba_Approx_V0 | threads=6 | batch=128 | 0.049286s
# Numba_Approx_V0 | threads=6 | batch=256 | 0.052074s
# Numba_Approx_V0 | threads=6 | batch=512 | 0.090423s
# Numba_Approx_V0 | threads=6 | batch=1024 | 0.095949s
#
# --- Numba_Approx_V1 ---
# Numba_Approx_V1 | threads=6 | batch=2 | 0.095695s
# Numba_Approx_V1 | threads=6 | batch=4 | 0.083225s
# Numba_Approx_V1 | threads=6 | batch=8 | 0.070260s
# Numba_Approx_V1 | threads=6 | batch=16 | 0.055900s
# Numba_Approx_V1 | threads=6 | batch=32 | 0.054794s
# Numba_Approx_V1 | threads=6 | batch=64 | 0.054501s
# Numba_Approx_V1 | threads=6 | batch=128 | 0.055250s
# Numba_Approx_V1 | threads=6 | batch=256 | 0.048325s
# Numba_Approx_V1 | threads=6 | batch=512 | 0.089610s
# Numba_Approx_V1 | threads=6 | batch=1024 | 0.092430s
#
# --- Para_Numba_Approx_V0 ---
# Para_Numba_Approx_V0 | threads=6 | batch=2 | 0.039550s
# Para_Numba_Approx_V0 | threads=6 | batch=4 | 0.037430s
# Para_Numba_Approx_V0 | threads=6 | batch=8 | 0.034659s
# Para_Numba_Approx_V0 | threads=6 | batch=16 | 0.030313s
# Para_Numba_Approx_V0 | threads=6 | batch=32 | 0.028747s
# Para_Numba_Approx_V0 | threads=6 | batch=64 | 0.030548s
# Para_Numba_Approx_V0 | threads=6 | batch=128 | 0.028773s
# Para_Numba_Approx_V0 | threads=6 | batch=256 | 0.037807s
# Para_Numba_Approx_V0 | threads=6 | batch=512 | 0.068387s
# Para_Numba_Approx_V0 | threads=6 | batch=1024 | 0.067253s

# %%
# -----------------------------
# SAVE CSV
# -----------------------------
file_name = 'omp_benchmark_parallel.csv'
with open(file_name, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["function", "threads", "batch_size", "time_sec"])
    writer.writerows(results)

print(f"\nSaved to {file_name}")
# Out:
# Saved to omp_benchmark_parallel.csv
